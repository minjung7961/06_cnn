# %%
# Codes are adapted from http://bit.ly/2U7ttYT (파이토치 첫걸음,한빛미디어)

# %% [markdown]
# # VGG19 Implementation
#
# - VGG-19
# - Convolution layer
# - Maxpooling layer
# - Fully connected layer

# %% [markdown]
# ## 1. Settings
# ### 1) Import required libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torch.utils.data as data
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %% [markdown]
# ### Hyperparameter

# %%
batch_size= 100
learning_rate = 0.001
num_epoch = 50

# %% [markdown]
# ### 2. Data Loader

# %%
# 이때 이미지들에 대한 변형도 같이 전달해줍니다.
transform_train = transforms.Compose([
            transforms.Resize(32),                   # 이미지 크기를 32x32으로 바꿔줍니다.
            transforms.RandomCrop(32, padding=4),        # 32x32 이미지의 랜덤한 위치에서 30x30 크기만큼 샘플링 합니다.
            transforms.RandomHorizontalFlip(),        # 랜덤한 확률로 이미지를 좌우반전 합니다.
            transforms.ToTensor(),                # 이미지 데이터를 텐서로 변형합니다.
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
             ])

transform_test = transforms.Compose([
    transforms.Resize(32),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

# %%
# CIFAR10 dataset
train_dataset = datasets.CIFAR10(root='./data/',
                                           train=True, 
                                           transform=transform_train,
                                           download=True)

test_dataset = datasets.CIFAR10(root='./data/',
                                          train=False, 
                                          transform=transform_test)

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 3. Model
# ### 1) Basic Blocks
#
# - 모델에 반복되는 부분이 많기 때문에 이를 함수로 만들어 단순화 합니다.
# - 맨 위에 이미지를 보면 컨볼루션 연산이 2번 연속하는 경우와 3번 연속하는 경우가 있는데 이를 각각 만들어줍니다.
# - 아래의 코드는 최적의 방법이라기 보다는 그림의 구조를 모방한 코드입니다.

# %%
# 컨볼루션 연산이 2번 연속하는 경우
# 컨볼루션-활성화함수-컨볼루션-활성화함수-풀링
def conv_2_block(in_dim,out_dim):
    model = nn.Sequential(
        nn.Conv2d(in_dim,out_dim,kernel_size=3,padding=1), # 인푹풋채널,아웃푹채널
        nn.BatchNorm2d(out_dim),
        nn.ReLU(),
        nn.Conv2d(out_dim,out_dim,kernel_size=3,padding=1),
        nn.BatchNorm2d(out_dim),
        nn.ReLU(),
        nn.MaxPool2d(2,2)
    )
    return model

  
# 컨볼루션 연산이 3번 연속하는 경우
# 컨볼루션-활성화함수-컨볼루션-활성화함수-컨볼루션-활성화함수-풀링

def conv_4_block(in_dim,out_dim): ## 노드안에 몇개있는지에따라 구현함
    model = nn.Sequential(
        nn.Conv2d(in_dim,out_dim,kernel_size=3,padding=1),
        nn.BatchNorm2d(out_dim),
        nn.ReLU(),
        nn.Conv2d(out_dim,out_dim,kernel_size=3,padding=1),
        nn.BatchNorm2d(out_dim),
        nn.ReLU(),
        nn.Conv2d(out_dim,out_dim,kernel_size=3,padding=1),
        nn.BatchNorm2d(out_dim),
        nn.ReLU(),
        nn.Conv2d(out_dim,out_dim,kernel_size=3,padding=1),
        nn.BatchNorm2d(out_dim),
        nn.ReLU(),
        nn.MaxPool2d(2,2)
    )
    return model

# %% [markdown]
# ### 2) VGG Model

# %%
# 위에서 정의한 블록들을 이용해 VGG 네트워크를 만들어보겠습니다.
# 필터의 개수가 2의 n승의 값을 가지기 때문에 base_dim이란 변수를 추가해서 단순화 했습니다.
# 현재 dog, cat 두 가지 클래스를 구분하려고 하기 때문에 num_classes=2로 설정했습니다.

class VGG(nn.Module):
    def __init__(self, base_dim, num_classes=10):
        super(VGG, self).__init__()
        self.feature = nn.Sequential(
            conv_2_block(3,base_dim), # 32 -> 16(maxpooling)
            conv_2_block(base_dim,2*base_dim), # 16 -> 8
            conv_4_block(2*base_dim,4*base_dim), # 8 -> 4
            conv_4_block(4*base_dim,8*base_dim), # 4 -> 2
            conv_4_block(8*base_dim,8*base_dim), # 2 -> 1      
        )
        self.fc_layer = nn.Sequential(
            nn.Linear(8*base_dim * 1 * 1, 1000), # 8*base_dim * 1 * 1 : 입력  1000 : 출력은 지맘대로
            nn.ReLU(True),                                   # True 는 inplace 연산을 하겠다는 의미를 가집니다. inplace 연산은 결과값을 새로운 변수에 값을 저장하는 대신 기존의 데이터를 대체하는것을 의미합니다.
            nn.Dropout(p=0.2),  
            nn.Linear(1000, 500),
            nn.ReLU(True),
            nn.Dropout(p=0.2),
            nn.Linear(500, num_classes), # 분류해야하는 개수
        )

    def forward(self, x):
        x = self.feature(x) 
        x = x.view(x.size(0), -1)                                               # x.size(0)를 batch size로 바꿔도 같은 값입니다.
        x = self.fc_layer(x)
        return x

# %%
32*32
# Out:
# 1024

# %% [markdown]
# ## 4. Optimizer & Loss

# %%
# gpu가 사용 가능한 경우에는 device를 0번 gpu로 설정하고 불가능하면 cpu로 설정합니다.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# 앞서 정의한대로 vGG 클래스를 인스턴스화 하고 지정한 장치에 올립니다.
model = VGG(base_dim=64) 
model = model.to(device) 

# 손실함수 및 최적화함수를 설정합니다.
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# 모델 자녀 노드의 이름과 모듈을 출력합니다.
for i in model.named_children():
    print(i)
# Out:
# cuda:0
# ('feature', Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU()
#     (12): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU()
#     (12): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU()
#     (12): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# ))
# ('fc_layer', Sequential(
#   (0): Linear(in_features=512, out_features=1000, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.2, inplace=False)
#   (3): Linear(in_features=1000, out_features=500, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.2, inplace=False)
#   (6): Linear(in_features=500, out_features=10, bias=True)
# ))

# %% [markdown]
# ## 5. Train

# %%
for i in range(num_epoch):
    correct = 0
    total = 0
    for j,[image,label] in enumerate(train_loader):
        x = image.to(device)
        y_= label.to(device)
        optimizer.zero_grad()
        outputs = model.forward(x)
        loss = loss_func(outputs,y_)
        loss.backward()
        optimizer.step()
        total += y_.size(0)
        _, predicted = torch.max(outputs.data, 1) # _는 받긴받는데 안쓰겠다 그리고 결과 확률들중에 가장높은확률의 클래스 확률과 레이블을 반환하겠다 이코드에서 확률은 변환안함
        correct += (predicted == y_).sum().item() # print 형태로 출력해보기위해 쓰는 코드
        if i%10 == 0:
            print('loss is ',loss)
            print('Test Accuracy is : {} %'.format(100 * correct / total))
# Out:
# loss is  tensor(0.0641, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 99.0 %
# loss is  tensor(0.0710, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 98.5 %
# loss is  tensor(0.1092, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 98.0 %
# loss is  tensor(0.0678, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 98.0 %
# loss is  tensor(0.0396, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 98.2 %
# loss is  tensor(0.2067, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.5 %
# loss is  tensor(0.0739, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.42857142857143 %
# loss is  tensor(0.0855, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.5 %
# loss is  tensor(0.0192, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.77777777777777 %
# loss is  tensor(0.1460, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.6 %
# loss is  tensor(0.1469, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.36363636363636 %
# loss is  tensor(0.0956, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.41666666666667 %
# loss is  tensor(0.0812, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.38461538461539 %
# loss is  tensor(0.1381, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.28571428571429 %
# loss is  tensor(0.1350, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.33333333333333 %
# loss is  tensor(0.0848, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.25 %
# loss is  tensor(0.1295, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.17647058823529 %
# loss is  tensor(0.0560, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.22222222222223 %
# loss is  tensor(0.0454, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.36842105263158 %
# loss is  tensor(0.0657, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.45 %
# loss is  tensor(0.1453, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.38095238095238 %
# loss is  tensor(0.1410, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.31818181818181 %
# loss is  tensor(0.0906, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.34782608695652 %
# loss is  tensor(0.0617, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.375 %
# loss is  tensor(0.0608, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.36 %
# loss is  tensor(0.2816, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.15384615384616 %
# loss is  tensor(0.0820, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.14814814814815 %
# loss is  tensor(0.1180, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.10714285714286 %
# loss is  tensor(0.0255, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.17241379310344 %
# loss is  tensor(0.1564, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.13333333333334 %
# loss is  tensor(0.0948, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.16129032258064 %
# loss is  tensor(0.2524, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 97.09375 %
# loss is  tensor(0.1616, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.96969696969697 %
# loss is  tensor(0.2944, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.8529411764706 %
# loss is  tensor(0.1426, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.8 %
# loss is  tensor(0.1580, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.83333333333333 %
# loss is  tensor(0.0627, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.83783783783784 %
# loss is  tensor(0.0561, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.89473684210526 %
# loss is  tensor(0.1092, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.87179487179488 %
# loss is  tensor(0.0161, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.95 %
# loss is  tensor(0.0775, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.95121951219512 %
# loss is  tensor(0.1405, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.95238095238095 %
# loss is  tensor(0.2618, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.83720930232558 %
# loss is  tensor(0.1810, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.79545454545455 %
# loss is  tensor(0.0869, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.8 %
# loss is  tensor(0.1661, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.78260869565217 %
# loss is  tensor(0.1011, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.7872340425532 %
# loss is  tensor(0.1979, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.72916666666667 %
# loss is  tensor(0.1464, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.71428571428571 %
# loss is  tensor(0.1672, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.68 %
# loss is  tensor(0.0450, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.72549019607843 %
# loss is  tensor(0.2061, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.65384615384616 %
# loss is  tensor(0.1100, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.64150943396227 %
# loss is  tensor(0.0601, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66666666666667 %
# loss is  tensor(0.0571, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.67272727272727 %
# loss is  tensor(0.1225, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.67857142857143 %
# loss is  tensor(0.1668, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66666666666667 %
# loss is  tensor(0.0920, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.65517241379311 %
# loss is  tensor(0.0455, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.67796610169492 %
# loss is  tensor(0.0774, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.71666666666667 %
# loss is  tensor(0.2105, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.70491803278688 %
# loss is  tensor(0.2458, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66129032258064 %
# loss is  tensor(0.0642, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6984126984127 %
# loss is  tensor(0.0974, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.71875 %
# loss is  tensor(0.2518, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66153846153846 %
# loss is  tensor(0.1177, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66666666666667 %
# loss is  tensor(0.1519, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.64179104477611 %
# loss is  tensor(0.0557, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66176470588235 %
# loss is  tensor(0.1189, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6376811594203 %
# loss is  tensor(0.1283, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.62857142857143 %
# loss is  tensor(0.0349, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66197183098592 %
# loss is  tensor(0.1363, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.63888888888889 %
# loss is  tensor(0.0742, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.64383561643835 %
# loss is  tensor(0.1085, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.63513513513513 %
# loss is  tensor(0.0629, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.64 %
# loss is  tensor(0.0999, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.64473684210526 %
# loss is  tensor(0.1302, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6103896103896 %
# loss is  tensor(0.1320, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.58974358974359 %
# loss is  tensor(0.0703, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.60759493670886 %
# loss is  tensor(0.0844, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6 %
# loss is  tensor(0.1378, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.5925925925926 %
# loss is  tensor(0.0364, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6219512195122 %
# loss is  tensor(0.1217, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.62650602409639 %
# loss is  tensor(0.1576, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.5952380952381 %
# loss is  tensor(0.0526, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6 %
# loss is  tensor(0.1324, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.59302325581395 %
# loss is  tensor(0.1761, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.57471264367815 %
# loss is  tensor(0.0586, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.5909090909091 %
# loss is  tensor(0.0867, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.59550561797752 %
# loss is  tensor(0.0809, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.61111111111111 %
# loss is  tensor(0.1152, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6043956043956 %
# loss is  tensor(0.0936, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.6195652173913 %
# loss is  tensor(0.1090, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.61290322580645 %
# loss is  tensor(0.0938, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.61702127659575 %
# loss is  tensor(0.1314, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.62105263157895 %
# loss is  tensor(0.0393, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.64583333333333 %
# loss is  tensor(0.0539, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.65979381443299 %
# loss is  tensor(0.1305, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.66326530612245 %
# loss is  tensor(0.0813, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.67676767676768 %
# loss is  tensor(0.1273, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.67 %
# loss is  tensor(0.1643, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.63366336633663 %
# loss is  tensor(0.1554, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.61764705882354 %
# loss is  tensor(0.1801, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.58252427184466 %
# loss is  tensor(0.1462, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.54807692307692 %
# loss is  tensor(0.1197, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.55238095238096 %
# loss is  tensor(0.2870, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.5377358490566 %
# loss is  tensor(0.1424, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.53271028037383 %
# loss is  tensor(0.2269, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.5 %
# loss is  tensor(0.1406, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.4954128440367 %
# loss is  tensor(0.1382, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.49090909090908 %
# loss is  tensor(0.1833, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.45945945945945 %
# loss is  tensor(0.1007, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.46428571428571 %
# loss is  tensor(0.1361, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.45132743362832 %
# loss is  tensor(0.1571, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.43859649122807 %
# loss is  tensor(0.2894, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.41739130434783 %
# loss is  tensor(0.0967, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.43103448275862 %
# loss is  tensor(0.1466, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.42735042735043 %
# loss is  tensor(0.0699, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.4322033898305 %
# loss is  tensor(0.0574, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.45378151260505 %
# loss is  tensor(0.2394, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.425 %
# loss is  tensor(0.0851, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.41322314049587 %
# loss is  tensor(0.1861, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.37704918032787 %
# loss is  tensor(0.1512, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.35772357723577 %
# loss is  tensor(0.0753, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.37096774193549 %
# loss is  tensor(0.2081, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.36 %
# loss is  tensor(0.1784, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34920634920636 %
# loss is  tensor(0.2549, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33070866141732 %
# loss is  tensor(0.1267, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.328125 %
# loss is  tensor(0.0621, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.1639, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31538461538462 %
# loss is  tensor(0.0365, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33587786259542 %
# loss is  tensor(0.0775, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3409090909091 %
# loss is  tensor(0.1292, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33082706766918 %
# loss is  tensor(0.1407, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32835820895522 %
# loss is  tensor(0.1274, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31851851851852 %
# loss is  tensor(0.1408, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30147058823529 %
# loss is  tensor(0.1142, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32116788321167 %
# loss is  tensor(0.0938, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.0924, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33812949640287 %
# loss is  tensor(0.0873, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33571428571429 %
# loss is  tensor(0.0537, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34751773049645 %
# loss is  tensor(0.1531, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33802816901408 %
# loss is  tensor(0.0993, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34265734265735 %
# loss is  tensor(0.1213, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34722222222223 %
# loss is  tensor(0.1940, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33793103448276 %
# loss is  tensor(0.1537, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32191780821918 %
# loss is  tensor(0.0482, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34013605442176 %
# loss is  tensor(0.1476, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32432432432432 %
# loss is  tensor(0.1516, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30872483221476 %
# loss is  tensor(0.0658, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32 %
# loss is  tensor(0.1404, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3112582781457 %
# loss is  tensor(0.0723, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3157894736842 %
# loss is  tensor(0.0626, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3202614379085 %
# loss is  tensor(0.1668, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31168831168831 %
# loss is  tensor(0.1854, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29032258064517 %
# loss is  tensor(0.1427, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28205128205128 %
# loss is  tensor(0.0603, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29299363057325 %
# loss is  tensor(0.1527, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29113924050633 %
# loss is  tensor(0.0795, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29559748427673 %
# loss is  tensor(0.0682, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3125 %
# loss is  tensor(0.0951, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32298136645963 %
# loss is  tensor(0.0631, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.1026, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33128834355828 %
# loss is  tensor(0.0956, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33536585365853 %
# loss is  tensor(0.1670, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32727272727273 %
# loss is  tensor(0.0756, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33734939759036 %
# loss is  tensor(0.2022, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32335329341318 %
# loss is  tensor(0.0695, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33928571428571 %
# loss is  tensor(0.2027, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33727810650888 %
# loss is  tensor(0.2460, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31176470588235 %
# loss is  tensor(0.0791, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3157894736842 %
# loss is  tensor(0.0977, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31976744186046 %
# loss is  tensor(0.1782, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3179190751445 %
# loss is  tensor(0.0497, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32758620689656 %
# loss is  tensor(0.0697, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33714285714285 %
# loss is  tensor(0.0975, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33522727272727 %
# loss is  tensor(0.0636, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33898305084746 %
# loss is  tensor(0.1495, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32584269662921 %
# loss is  tensor(0.1121, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31284916201118 %
# loss is  tensor(0.1437, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31666666666666 %
# loss is  tensor(0.0843, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32044198895028 %
# loss is  tensor(0.2596, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3076923076923 %
# loss is  tensor(0.1185, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31147540983606 %
# loss is  tensor(0.2130, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29891304347827 %
# loss is  tensor(0.0615, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3027027027027 %
# loss is  tensor(0.0731, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30645161290323 %
# loss is  tensor(0.1383, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31016042780749 %
# loss is  tensor(0.0303, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32978723404256 %
# loss is  tensor(0.0824, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.1044, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33684210526316 %
# loss is  tensor(0.1863, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31937172774869 %
# loss is  tensor(0.0991, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32291666666667 %
# loss is  tensor(0.1110, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32642487046633 %
# loss is  tensor(0.1420, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31958762886597 %
# loss is  tensor(0.0831, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32307692307693 %
# loss is  tensor(0.1280, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31122448979592 %
# loss is  tensor(0.1276, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30964467005076 %
# loss is  tensor(0.1888, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29292929292929 %
# loss is  tensor(0.1067, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2964824120603 %
# loss is  tensor(0.1449, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29 %
# loss is  tensor(0.0596, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29850746268657 %
# loss is  tensor(0.1889, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2871287128713 %
# loss is  tensor(0.0942, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29064039408867 %
# loss is  tensor(0.1988, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2843137254902 %
# loss is  tensor(0.1299, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28292682926829 %
# loss is  tensor(0.3379, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26699029126213 %
# loss is  tensor(0.0347, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28502415458937 %
# loss is  tensor(0.2310, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26923076923077 %
# loss is  tensor(0.1211, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26794258373205 %
# loss is  tensor(0.1540, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25714285714285 %
# loss is  tensor(0.1394, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25592417061611 %
# loss is  tensor(0.0444, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26415094339623 %
# loss is  tensor(0.1418, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25352112676056 %
# loss is  tensor(0.0837, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25233644859813 %
# loss is  tensor(0.0955, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25116279069768 %
# loss is  tensor(0.0616, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26388888888889 %
# loss is  tensor(0.1173, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26728110599079 %
# loss is  tensor(0.1330, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26605504587155 %
# loss is  tensor(0.2032, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2420091324201 %
# loss is  tensor(0.1065, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24545454545455 %
# loss is  tensor(0.1539, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23529411764706 %
# loss is  tensor(0.1356, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22072072072072 %
# loss is  tensor(0.1089, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.21973094170404 %
# loss is  tensor(0.0810, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23214285714286 %
# loss is  tensor(0.0886, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23555555555555 %
# loss is  tensor(0.0853, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2433628318584 %
# loss is  tensor(0.0731, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2511013215859 %
# loss is  tensor(0.0844, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25438596491227 %
# loss is  tensor(0.3279, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24454148471615 %
# loss is  tensor(0.0894, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24347826086957 %
# loss is  tensor(0.3458, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22510822510823 %
# loss is  tensor(0.1528, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.21551724137932 %
# loss is  tensor(0.1166, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.21459227467811 %
# loss is  tensor(0.0638, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22649572649573 %
# loss is  tensor(0.0990, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22978723404255 %
# loss is  tensor(0.2066, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.21610169491525 %
# loss is  tensor(0.1375, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22362869198312 %
# loss is  tensor(0.1957, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.21848739495799 %
# loss is  tensor(0.0897, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22175732217573 %
# loss is  tensor(0.0627, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23333333333333 %
# loss is  tensor(0.1402, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22821576763485 %
# loss is  tensor(0.0732, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23553719008264 %
# loss is  tensor(0.1321, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23868312757202 %
# loss is  tensor(0.0781, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24590163934427 %
# loss is  tensor(0.1046, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24489795918367 %
# loss is  tensor(0.1417, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2479674796748 %
# loss is  tensor(0.1374, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24696356275304 %
# loss is  tensor(0.1321, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24596774193549 %
# loss is  tensor(0.1893, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24497991967871 %
# loss is  tensor(0.1065, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.252 %
# loss is  tensor(0.1582, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24701195219123 %
# loss is  tensor(0.0468, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2579365079365 %
# loss is  tensor(0.0663, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26086956521739 %
# loss is  tensor(0.0371, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2755905511811 %
# loss is  tensor(0.1173, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27450980392157 %
# loss is  tensor(0.0710, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28515625 %
# loss is  tensor(0.1365, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.284046692607 %
# loss is  tensor(0.2372, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27906976744185 %
# loss is  tensor(0.0596, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2895752895753 %
# loss is  tensor(0.0709, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29230769230769 %
# loss is  tensor(0.0653, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29885057471265 %
# loss is  tensor(0.0254, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31297709923665 %
# loss is  tensor(0.1615, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30418250950571 %
# loss is  tensor(0.0819, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30681818181819 %
# loss is  tensor(0.1074, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30566037735849 %
# loss is  tensor(0.2536, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30451127819549 %
# loss is  tensor(0.0777, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30337078651685 %
# loss is  tensor(0.1555, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29477611940298 %
# loss is  tensor(0.1381, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2899628252788 %
# loss is  tensor(0.1137, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28518518518518 %
# loss is  tensor(0.0436, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29520295202953 %
# loss is  tensor(0.0961, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30147058823529 %
# loss is  tensor(0.1542, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31135531135531 %
# loss is  tensor(0.0603, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31751824817518 %
# loss is  tensor(0.1315, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31272727272727 %
# loss is  tensor(0.0602, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31884057971014 %
# loss is  tensor(0.1086, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31768953068593 %
# loss is  tensor(0.0244, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33093525179856 %
# loss is  tensor(0.1971, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3225806451613 %
# loss is  tensor(0.1008, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32142857142857 %
# loss is  tensor(0.1756, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3202846975089 %
# loss is  tensor(0.0902, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31914893617021 %
# loss is  tensor(0.0398, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32508833922262 %
# loss is  tensor(0.1798, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32394366197182 %
# loss is  tensor(0.0778, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32982456140351 %
# loss is  tensor(0.0801, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33566433566433 %
# loss is  tensor(0.0583, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34146341463415 %
# loss is  tensor(0.0821, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34722222222223 %
# loss is  tensor(0.2072, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33564013840831 %
# loss is  tensor(0.0441, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34482758620689 %
# loss is  tensor(0.1585, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34020618556701 %
# loss is  tensor(0.2275, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32876712328768 %
# loss is  tensor(0.0787, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33788395904436 %
# loss is  tensor(0.2031, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3265306122449 %
# loss is  tensor(0.1384, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33220338983051 %
# loss is  tensor(0.2056, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32094594594595 %
# loss is  tensor(0.0286, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.0992, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33892617449665 %
# loss is  tensor(0.1803, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33779264214047 %
# loss is  tensor(0.0321, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34666666666666 %
# loss is  tensor(0.1195, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34551495016612 %
# loss is  tensor(0.0244, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3543046357616 %
# loss is  tensor(0.1247, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.35643564356435 %
# loss is  tensor(0.1610, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.35197368421052 %
# loss is  tensor(0.0831, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.36065573770492 %
# loss is  tensor(0.0614, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.36601307189542 %
# loss is  tensor(0.0542, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.37133550488599 %
# loss is  tensor(0.0879, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.37662337662337 %
# loss is  tensor(0.1165, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.37216828478964 %
# loss is  tensor(0.0652, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3741935483871 %
# loss is  tensor(0.1068, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.37620578778134 %
# loss is  tensor(0.2828, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.36217948717949 %
# loss is  tensor(0.1572, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.36102236421725 %
# loss is  tensor(0.1495, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.35668789808918 %
# loss is  tensor(0.1959, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34603174603174 %
# loss is  tensor(0.2656, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33227848101266 %
# loss is  tensor(0.1330, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33123028391167 %
# loss is  tensor(0.1100, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33018867924528 %
# loss is  tensor(0.1206, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32915360501568 %
# loss is  tensor(0.0468, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3375 %
# loss is  tensor(0.1534, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.1937, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32608695652173 %
# loss is  tensor(0.0901, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.328173374613 %
# loss is  tensor(0.0506, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.0799, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33846153846154 %
# loss is  tensor(0.0934, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.34049079754601 %
# loss is  tensor(0.1402, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33639143730886 %
# loss is  tensor(0.1945, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32621951219512 %
# loss is  tensor(0.0664, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32826747720365 %
# loss is  tensor(0.1210, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33333333333333 %
# loss is  tensor(0.0983, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.33534743202416 %
# loss is  tensor(0.2062, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31927710843374 %
# loss is  tensor(0.1469, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31831831831832 %
# loss is  tensor(0.1892, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31137724550898 %
# loss is  tensor(0.0929, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31343283582089 %
# loss is  tensor(0.0388, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32142857142857 %
# loss is  tensor(0.0959, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32344213649851 %
# loss is  tensor(0.2096, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31360946745562 %
# loss is  tensor(0.2726, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30678466076697 %
# loss is  tensor(0.0777, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31176470588235 %
# loss is  tensor(0.1559, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30791788856305 %
# loss is  tensor(0.0697, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31286549707602 %
# loss is  tensor(0.2303, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3061224489796 %
# loss is  tensor(0.0773, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31104651162791 %
# loss is  tensor(0.1531, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30724637681159 %
# loss is  tensor(0.0314, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31502890173411 %
# loss is  tensor(0.1124, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31123919308358 %
# loss is  tensor(0.1281, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3132183908046 %
# loss is  tensor(0.0890, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31805157593124 %
# loss is  tensor(0.1412, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31714285714285 %
# loss is  tensor(0.0998, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32193732193733 %
# loss is  tensor(0.1223, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32386363636364 %
# loss is  tensor(0.1425, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3201133144476 %
# loss is  tensor(0.1752, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.31920903954803 %
# loss is  tensor(0.1300, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32676056338028 %
# loss is  tensor(0.1720, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.32303370786516 %
# loss is  tensor(0.1626, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3109243697479 %
# loss is  tensor(0.1619, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3072625698324 %
# loss is  tensor(0.1631, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30640668523677 %
# loss is  tensor(0.2066, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29722222222222 %
# loss is  tensor(0.1676, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28808864265928 %
# loss is  tensor(0.0656, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29005524861878 %
# loss is  tensor(0.1308, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28650137741047 %
# loss is  tensor(0.1141, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28846153846153 %
# loss is  tensor(0.3314, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27945205479452 %
# loss is  tensor(0.0733, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28142076502732 %
# loss is  tensor(0.1619, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26975476839237 %
# loss is  tensor(0.1131, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27445652173913 %
# loss is  tensor(0.0842, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27913279132791 %
# loss is  tensor(0.0776, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28108108108108 %
# loss is  tensor(0.1621, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28301886792453 %
# loss is  tensor(0.0823, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28494623655914 %
# loss is  tensor(0.1246, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28418230563003 %
# loss is  tensor(0.1201, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28342245989305 %
# loss is  tensor(0.0449, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.288 %
# loss is  tensor(0.1167, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2872340425532 %
# loss is  tensor(0.0793, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29177718832891 %
# loss is  tensor(0.0819, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29100529100529 %
# loss is  tensor(0.1522, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29023746701847 %
# loss is  tensor(0.1412, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28421052631579 %
# loss is  tensor(0.0760, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28871391076116 %
# loss is  tensor(0.1894, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28534031413612 %
# loss is  tensor(0.0944, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28720626631853 %
# loss is  tensor(0.0634, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29427083333333 %
# loss is  tensor(0.0632, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3012987012987 %
# loss is  tensor(0.1093, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30310880829016 %
# loss is  tensor(0.1811, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30232558139535 %
# loss is  tensor(0.1329, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29896907216495 %
# loss is  tensor(0.0705, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30334190231362 %
# loss is  tensor(0.1635, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3025641025641 %
# loss is  tensor(0.1171, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30179028132993 %
# loss is  tensor(0.2186, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28826530612245 %
# loss is  tensor(0.1424, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2849872773537 %
# loss is  tensor(0.2318, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27664974619289 %
# loss is  tensor(0.1440, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28101265822785 %
# loss is  tensor(0.1533, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27525252525253 %
# loss is  tensor(0.0716, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27959697732997 %
# loss is  tensor(0.1993, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27889447236181 %
# loss is  tensor(0.1575, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2781954887218 %
# loss is  tensor(0.1257, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2775 %
# loss is  tensor(0.1084, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27680798004988 %
# loss is  tensor(0.1075, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27611940298507 %
# loss is  tensor(0.2584, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26054590570719 %
# loss is  tensor(0.1272, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26485148514851 %
# loss is  tensor(0.0543, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27160493827161 %
# loss is  tensor(0.0724, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27832512315271 %
# loss is  tensor(0.0766, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28255528255528 %
# loss is  tensor(0.0605, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2843137254902 %
# loss is  tensor(0.1106, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2885085574572 %
# loss is  tensor(0.0833, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29024390243903 %
# loss is  tensor(0.1188, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28953771289538 %
# loss is  tensor(0.1231, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29368932038835 %
# loss is  tensor(0.1329, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29055690072639 %
# loss is  tensor(0.1384, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28743961352657 %
# loss is  tensor(0.0854, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28915662650603 %
# loss is  tensor(0.0835, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29086538461539 %
# loss is  tensor(0.0316, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29736211031175 %
# loss is  tensor(0.0973, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30143540669856 %
# loss is  tensor(0.0698, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30310262529832 %
# loss is  tensor(0.1874, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29523809523809 %
# loss is  tensor(0.0604, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29928741092637 %
# loss is  tensor(0.0921, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30094786729858 %
# loss is  tensor(0.1191, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29550827423168 %
# loss is  tensor(0.0562, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2995283018868 %
# loss is  tensor(0.0711, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30117647058823 %
# loss is  tensor(0.0579, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30516431924883 %
# loss is  tensor(0.1152, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30210772833723 %
# loss is  tensor(0.0964, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.30140186915888 %
# loss is  tensor(0.1285, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.3006993006993 %
# loss is  tensor(0.2038, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2953488372093 %
# loss is  tensor(0.1814, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29234338747099 %
# loss is  tensor(0.1064, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29629629629629 %
# loss is  tensor(0.2219, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.29099307159353 %
# loss is  tensor(0.2606, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28110599078342 %
# loss is  tensor(0.0341, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28735632183908 %
# loss is  tensor(0.0873, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28899082568807 %
# loss is  tensor(0.1572, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28604118993135 %
# loss is  tensor(0.2603, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27625570776256 %
# loss is  tensor(0.0394, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.28246013667426 %
# loss is  tensor(0.2418, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.27272727272727 %
# loss is  tensor(0.1260, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26984126984127 %
# loss is  tensor(0.2423, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26244343891403 %
# loss is  tensor(0.1123, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26185101580135 %
# loss is  tensor(0.0619, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26801801801801 %
# loss is  tensor(0.1716, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.26741573033708 %
# loss is  tensor(0.3076, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25784753363229 %
# loss is  tensor(0.1899, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25727069351231 %
# loss is  tensor(0.1356, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25223214285714 %
# loss is  tensor(0.1445, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25167037861915 %
# loss is  tensor(0.0616, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25777777777778 %
# loss is  tensor(0.0702, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25942350332595 %
# loss is  tensor(0.1897, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25 %
# loss is  tensor(0.1638, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24503311258277 %
# loss is  tensor(0.1532, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24449339207048 %
# loss is  tensor(0.0975, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24835164835164 %
# loss is  tensor(0.1470, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24561403508773 %
# loss is  tensor(0.1289, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24507658643326 %
# loss is  tensor(0.0729, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24890829694323 %
# loss is  tensor(0.1961, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2483660130719 %
# loss is  tensor(0.1504, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24782608695652 %
# loss is  tensor(0.2955, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23427331887201 %
# loss is  tensor(0.0973, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23593073593074 %
# loss is  tensor(0.0857, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2354211663067 %
# loss is  tensor(0.1331, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23922413793103 %
# loss is  tensor(0.0572, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24516129032259 %
# loss is  tensor(0.0584, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2510729613734 %
# loss is  tensor(0.1521, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24625267665952 %
# loss is  tensor(0.0846, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.25 %
# loss is  tensor(0.0995, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24946695095949 %
# loss is  tensor(0.1002, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24893617021277 %
# loss is  tensor(0.1401, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24628450106157 %
# loss is  tensor(0.1876, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24152542372882 %
# loss is  tensor(0.1458, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2431289640592 %
# loss is  tensor(0.0967, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24050632911393 %
# loss is  tensor(0.1515, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24 %
# loss is  tensor(0.2020, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23529411764706 %
# loss is  tensor(0.1236, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23480083857443 %
# loss is  tensor(0.1018, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24058577405857 %
# loss is  tensor(0.1085, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23799582463465 %
# loss is  tensor(0.1458, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23541666666667 %
# loss is  tensor(0.0771, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23700623700624 %
# loss is  tensor(0.0621, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24066390041494 %
# loss is  tensor(0.0803, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24430641821947 %
# loss is  tensor(0.1575, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2396694214876 %
# loss is  tensor(0.1022, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24123711340206 %
# loss is  tensor(0.0420, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2448559670782 %
# loss is  tensor(0.2357, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24024640657085 %
# loss is  tensor(0.1378, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23770491803279 %
# loss is  tensor(0.2023, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23721881390593 %
# loss is  tensor(0.0524, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23877551020408 %
# loss is  tensor(0.1465, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23421588594705 %
# loss is  tensor(0.1000, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23780487804878 %
# loss is  tensor(0.1292, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2393509127789 %
# loss is  tensor(0.3425, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.2327935222672 %
# loss is  tensor(0.1697, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23030303030303 %
# loss is  tensor(0.0804, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22983870967742 %
# loss is  tensor(0.1955, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.22937625754527 %
# loss is  tensor(0.0586, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.23293172690764 %
# loss is  tensor(0.0545, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.24048096192385 %
# loss is  tensor(0.1648, device='cuda:0', grad_fn=<NllLossBackward>)
# Test Accuracy is : 96.234 %

# %% [markdown]
# ## 모델 저장하기

# %%
PATH = './saveModel/'
torch.save(model.state_dict(), PATH+'VGG19_CIFAR10_state')

# %%
# 불러오기
model1 = model.load_state_dict(torch.load(PATH+'VGG19_CIFAR10_state'))

# %% [markdown]
# ### 전체 모델 저장하기/불러오기

# %%
torch.save(model, PATH+'VGG19_CIFAR10_orgin')

# %%
model1 = torch.load(PATH+'VGG19_CIFAR10_orgin')

# %% [markdown]
# ## test

# %%
# Test the model again using the saved weight file
model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Test Accuracy of the model on the 10000 test images: 89.48 %
